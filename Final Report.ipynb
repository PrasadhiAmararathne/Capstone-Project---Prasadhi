# %% [markdown]
# # Analysis of Boroughs of Toronto for Residential Preferences

# %% [markdown]
# ## Introduction

# %% [markdown]
# Toronto is the capital city of the Canadian province of Ontario. With a recorded population of 6,254,571 in 2021, it is the most populous city in Canada and the fourth most populous city in North America. The city is the anchor of the Golden Horseshoe, an urban agglomeration of 9,245,438 people (as of 2016) surrounding the western end of Lake Ontario. Toronto is an international centre of business, finance, arts, and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world
# When it comes to immigrants Toronto is staggeringly popular among them. The city’s immigrant population has been growing steadily over the past several decades, now with immigrants making up nearly half of the total population and with more than half of the population identifying as a member of a visible minority community.
#
# When studied the reasons for the city's popularity among immigrants following reasons were highlighted.
#
# Employment: Toronto has one of the strongest economies in the country. There are many job opportunities across a range of industries. Most recently, Toronto has been ranked as one of the leading tech-jobs markets in North America, making it an extremely attractive destination for those working in computer programming, software engineering, and database management positions.
#
# Culture: The city is well-known for its vibrant cultural offerings. The city has exquisite cuisines from around the world, incredible cultural neighbourhoods, like Chinatown and Little Italy, and some amazing artistic companies and festivals. Every year the city hosts the Toronto International Film Festival (TIFF), one of the most well-known film festivals in the world, and plays home to the prestigious Toronto Symphony Orchestra (TSO) and the renowned National Ballet of Canada.
#
# Diversity: According to the 2016 census, immigrants made up a staggering 49% of the city’s population. While this number may seem high, it makes sense when considering the many different cultures, neighbourhoods, and activities offered by the city. Toronto has always celebrated its range of population, touting diversity as a strength, even being named the most diverse city in the world by BBC Radio in 2016.
#
# Access to Services: Toronto has a robust public transit system, allowing its residents to travel quickly and easily throughout the city using subways, busses, streetcars, and GoTrains. As well, as with every city in Canada, citizens and permanent residents have access to universal healthcare and social services. This means that residents can access the many hospitals and community services which promote their health and well-being.

# %% [markdown]
# ### Purpose of the study

# %% [markdown]
# Through this project I will be analyzing different boroughs of Toronto and concluding my results based on different socio economic factors.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Data Description

# %% [markdown]
# Following Data were used in the study
#
# Information of number of neighborhoods in Toronto and their corresponding coordinate and borough in which it belongs to. Data acquired through below link
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# Foursquare that contains the information of retail stores in a neighborhood. Types of retails store,nameandcoordinatewillbeobtainedthroughAPIcallonFoursquare.

# %% [markdown]
# ### Analysis

# %% [markdown]
# The 103 neighborhoods can be visualized in the following map plot created by folium library.

# %% [markdown]
# ![Toronto%20Map.PNG](attachment:Toronto%20Map.PNG)

# %% [markdown]
# The city was further analyzed to identify the venues along with the neighbourhood.

# %% [markdown]
# ![Nearby%20Venues.PNG](attachment:Nearby%20Venues.PNG)

# %% [markdown]
# ![nearby%20venues%202.PNG](attachment:nearby%20venues%202.PNG)

# %% [markdown]
# Neighbourhood venues were further categorized and for each subarb I was able to find the most frequent type of venues separately

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# Complete list of above analysis can be found in the notebook.

# %% [markdown]
# Importance of above analysis is the insight it provides to each and every neighbourhood. If you go through the list you can notice that even though it is within the same city, the most frequent venues are different in almost every neighbourhood. Based on these we can get an idea of the socioeconomic parameters of the popoulation that resides in the area.
#
# For example there are neighbourhoods which has a higher number of Japanese or Mexican restaurants, based on that we can come to an idea regarding the food preferences of the certain neighbourhood. Likewise the above study can be much useful when it comes to deciding a borough to reside in Toronto. Based on each person's preference they can get a clear idea as into which borough would provide them the facilities that they expect from their residence area

# %% [markdown]
# Using K mean clustering I have clustered the neighbourhood based on the above analysis which can be depicted in a map as below.

# %% [markdown]
# ![Clustered%20Map.PNG](attachment:Clustered%20Map.PNG)

# %% [markdown]
# To be able to have a understanding of the living arrangements of these boroughs I have included two more factors to the study.
# 1. Housing Prices
# 2. School Ratings

# %% [markdown]
# Above two factors can be considered as two of the most important factors people consider when they move to another city or country. Everyone makes a decision to move in order to make a better future for themselves. In order to do that they should get as much as information regarding the area they are moving in to.
# It is important that the change they are making to be affordable for their income levels also it should provide facilities which matches their expectations.
# Based on above two factors following charts can be drawn to reflect areas of Toronto

# %% [markdown]
# ![housing%20prices.PNG](attachment:housing%20prices.PNG)

# %% [markdown]
# This the housing price chart of Toronto, for different areas the prices can vary

# %% [markdown]
# ![school%20rating.PNG](attachment:school%20rating.PNG)

# %% [markdown]
# This chart shows the school rating of different areas

# %% [markdown]
# For each and every area there can be pros and cons, for example in an area where the housing price is low, school rating can be low as well. But there are some areas where it is not the same case. Above study can be used in a way to identify and compare these pros and cons and decide on the optimal solution

# %% [markdown]
# ## Conclusion

# %% [markdown]
# When we need to choose a place to reside for long term there are many factors that should be considered. It is not enough to consider the living cost of a certain city and decide that it would be the best choice as it is afforadable. As shown in this study within the same city there can be many differences in each small area.
# Therefore when making such a decision it is important to analyze the decision based on different areas. As shown in the study we can consider
# 1. Socio economic parameters
# 2. Neighborhood conditions
# 3. Facilities available in the neighbourhood
# 4. How the area matches to your way of living
# 5. Housing Prices
# 6. School ratings
#
# Shown in the study are only few factors that can be compared against each other and can be used as inputs in order to make the best suited decision.
